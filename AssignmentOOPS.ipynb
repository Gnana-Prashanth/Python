# %% [markdown]
#  Q1. Write a Python program to demonstrate multiple inheritance.
#  1. Employee class has 3 data members EmployeeID, Gender (String), Salary and
#  PerformanceRating(Out of 5) of type int. It has a get() function to get these details from
#  the user.
#  2. JoiningDetail class has a data member DateOfJoining of type Date and a function
#  getDoJ to get the Date of joining of employees.
#  3. Information Class uses the marks from Employee class and the DateOfJoining date
#  from the JoiningDetail class to calculate the top 3 Employees based on their Ratings
#  and then Display, using readData, all the details on these employees in Ascending
#  order of their Date Of Joining

# %%
from datetime import datetime

class Employee:
    def __init__(self):
        self.EmployeeID = None
        self.Gender = None
        self.Salary = None
        self.PerformanceRating = None

    def get(self):
        self.EmployeeID = input("Enter Employee ID: ")
        self.Gender = input("Enter Gender: ")
        self.Salary = float(input("Enter Salary: "))
        self.PerformanceRating = int(input("Enter Performance Rating (out of 5): "))


class JoiningDetail:
    def __init__(self):
        self.DateOfJoining = None

    def getDoJ(self):
        date_str = input("Enter Date of Joining (DD-MM-YYYY): ")
        self.DateOfJoining = datetime.strptime(date_str, "%d-%m-%Y")


class Information(Employee, JoiningDetail):
    def __init__(self):
        Employee.__init__(self)
        JoiningDetail.__init__(self)

    def readData(self):
        print(f"Employee ID: {self.EmployeeID}")
        print(f"Gender: {self.Gender}")
        print(f"Salary: {self.Salary}")
        print(f"Performance Rating: {self.PerformanceRating}")
        print(f"Date of Joining: {self.DateOfJoining.strftime('%d-%m-%Y')}")
        print("-" * 40)


# ---------- Main Program ----------
n = int(input("Enter number of employees: "))
employees = []

for i in range(n):
    print(f"\nEnter details for Employee {i + 1}:")
    emp = Information()
    emp.get()
    emp.getDoJ()
    employees.append(emp)

top_employees = sorted(employees, key=lambda x: x.PerformanceRating, reverse=True)[:3]

top_employees.sort(key=lambda x: x.DateOfJoining)

print("\nTop 3 Employees based on Performance Rating (sorted by Date of Joining):")
for emp in top_employees:
    emp.readData()
# Out:
# Enter number of employees: 4
#
# Enter details for Employee 1:
# Enter Employee ID: 1
# Enter Gender: m
# Enter Salary: 1000
# Enter Performance Rating (out of 5): 1
# Enter Date of Joining (DD-MM-YYYY): 11-11-2011
#
# Enter details for Employee 2:
# Enter Employee ID: 2
# Enter Gender: f
# Enter Salary: 1200
# Enter Performance Rating (out of 5): 1
# Enter Date of Joining (DD-MM-YYYY): 11-12-2011
#
# Enter details for Employee 3:
# Enter Employee ID: 3
# Enter Gender: f
# Enter Salary: 1500
# Enter Performance Rating (out of 5): 2
# Enter Date of Joining (DD-MM-YYYY): 11-01-2011
#
# Enter details for Employee 4:
# Enter Employee ID: 4
# Enter Gender: f
# Enter Salary: 1900
# Enter Performance Rating (out of 5): 3
# Enter Date of Joining (DD-MM-YYYY): 01-01-2011
#
# Top 3 Employees based on Performance Rating (sorted by Date of Joining):
# Employee ID: 4
# Gender: f
# Salary: 1900.0
# Performance Rating: 3
# Date of Joining: 01-01-2011
# ----------------------------------------
# Employee ID: 3
# Gender: f
# Salary: 1500.0
# Performance Rating: 2
# Date of Joining: 11-01-2011
# ----------------------------------------
# Employee ID: 1
# Gender: m
# Salary: 1000.0
# Performance Rating: 1
# Date of Joining: 11-11-2011
# ----------------------------------------

# %% [markdown]
#  Q.2 Write a Python program to demonstrate Polymorphism.
#  1. Class Vehicle with a parameterized function Fare, that takes input value as fare and
#  returns it to calling Objects.
#  2. Create five separate variables Bus, Car, Train, Truck and Ship that call the Fare
#  function.
#  3. Use a third variable TotalFare to store the sum of fare for each Vehicle Type.
#  4. Print the TotalFare.

# %%
class Vehicle:
  def Fare(self,fare):
    return fare

Bus = Vehicle()
Car = Vehicle()
Train = Vehicle()
Truck = Vehicle()
Ship = Vehicle()

bus_fare = Bus.Fare(200)
car_fare = Car.Fare(100)
train_fare = Train.Fare(150)
truck_fare = Truck.Fare(250)
ship_fare = Ship.Fare(500)

TotalFare = bus_fare + car_fare + train_fare + truck_fare + ship_fare

print("Total Fare for all vehicles is:",TotalFare)
# Out:
# Total Fare for all vehicles is: 1200

# %% [markdown]
#  Q3. Consider an ongoing test cricket series. Following are the names of the players and their
#  scores in the test1 and 2.
#
#
#  Test Match 1 :
#  Dhoni : 56 , Balaji : 94
#
#
#  Test Match 2 :
#  Balaji : 80 , Dravid : 105
#
#
#  Calculate the highest number of runs scored by an individual cricketer in both of the matches.
#  Create  a python function Max_Score (M)  that reads a dictionary M  that recognizes the player
#  with the highest total score.  This function will return ( Top player , Total Score ) . You can
#  consider the Top player as String who is the highest scorer   and Top score as Integer.
#
#
#  Input : Max_Score({‘test1’:{‘Dhoni’:56, ‘Balaji : 85}, ‘test2’:{‘Dhoni’ 87, ‘Balaji ’:200}})

# %%
def Max_Score(M):
  total = {}

  for match in M.values():
    for player, score in match.items():
      total[player] = total.get(player,0) + score

  top_player = max(total, key=total.get)
  top_score = total[top_player]

  return(top_player,top_score)

M = {
    'test1':{'Dhoni':56, 'Balaji':94},
    'test2':{'Balaji':80,'Dravid':105}
}

print(Max_Score(M))
# Out:
# ('Balaji', 174)

# %% [markdown]
# Q4. Create a simple Card game in which there are 8 cards which are randomly chosen from a
#  deck.  The first card is shown face up. The game asks the player to predict whether the next card
#  in the selection will have a higher or lower value than the currently showing card.
#
#  For example, say the card that’s shown is a 3. The player chooses “higher,” and the next card is
#  shown. If that card has a higher value, the player is correct. In this example, if the player had
#  chosen “lower,” they would have been incorrect. If the player guesses correctly, they get 20
#  points. If they choose incorrectly, they lose 15 points. If the next card to be turned over has the
#  same value as the previous card, the player is incorrect

# %%
import random

def card_game():
  deck = list(range(1,14))

  cards = random.sample(deck,8)
  score = 0

  print("🔶 Welcome to the Higher or Lower game! 🔶")
  print("Let's Beginn!❤️‍🔥")

  current_card =cards[0]
  print("First card is:",current_card)

  for next_card in cards[1:]:
    guess = input("Will the next card be higher or lower? (h/l): ").lower()

    print("Next card is:",next_card)

    if guess == 'h':
      if next_card > current_card:
        print("☑️Correct you gain 20 points")
        score += 20
      else:
        print("✖️Wrong! you lose 15 points")
        score -= 15

    elif guess == 'l':
      if next_card < current_card:
        print("☑️Correct you gain 20 points")
        score += 20
      else:
        print("✖️Wrong! you lose 15 points")
        score -= 15

    else:
      print("⚠️Invalid choice! Type 'h' for higher or 'l' for lower")

      current_card = next_card

      print("Current score:", score)
      print("--------------------------------------")

  print("🎯Game Over! Your Final Score is:", score)

card_game()
# Out:
# 🔶 Welcome to the Higher or Lower game! 🔶
# Let's Beginn!❤️‍🔥
# First card is: 5
# Will the next card be higher or lower? (h/l): l
# Next card is: 7
# ✖️Wrong! you lose 15 points
# Will the next card be higher or lower? (h/l): l
# Next card is: 2
# ☑️Correct you gain 20 points
# Will the next card be higher or lower? (h/l): h
# Next card is: 1
# ✖️Wrong! you lose 15 points
# Will the next card be higher or lower? (h/l): l
# Next card is: 12
# ✖️Wrong! you lose 15 points
# Will the next card be higher or lower? (h/l): h
# Next card is: 10
# ☑️Correct you gain 20 points
# Will the next card be higher or lower? (h/l): l
# Next card is: 13
# ✖️Wrong! you lose 15 points
# Will the next card be higher or lower? (h/l): l
# Next card is: 11
# ✖️Wrong! you lose 15 points
# 🎯Game Over! Your Final Score is: -35

# %% [markdown]
#  Q5. Create an empty  dictionary called  Car_0  . Then fill the dictionary with Keys : color , speed
#  , X_position and Y_position.
#
#
#  car_0 = {'x_position': 10, 'y_position': 72, 'speed': 'medium'} .
#
#  a) If the speed is slow  the  coordinates of the  X_pos get incremented by 2.
#
#  b) If the speed is Medium  the  coordinates of the  X_pos gets incremented by 9
#
#  c) Now if the speed is Fast the  coordinates of the  X_pos gets incremented by  22.
#
#
#  Print the modified dictionary

# %%
car_0 = {}

car_0 = {
    'color':'red',
    'speed':'medium',
    'x_position':10,
    'y_position':72
}

print(" Original car details:", car_0)

if car_0['speed'] == 'slow':
  x_increment = 2
elif car_0['speed'] == 'medium':
  x_increment = 9
elif car_0['speed'] == 'fast':
  x_increment = 22
else:
  x_increment = 0

car_0['x_position'] += x_increment

print("\n✅Modified car details:", car_0)
# Out:
#  Original car details: {'color': 'red', 'speed': 'medium', 'x_position': 10, 'y_position': 72}
#
# ✅Modified car details: {'color': 'red', 'speed': 'medium', 'x_position': 19, 'y_position': 72}

# %% [markdown]
#  Q6. Show a basic implementation of abstraction in python using the abstract classes.
#  1. Create an abstract class in python.
#  2. Implement abstraction with the other classes and base class as abstract class

# %%
from abc import ABC, abstractmethod

class Vehicle(ABC):
  def max_speed(self): #abstract method
    pass

class car(Vehicle):
  def max_speed(self):
    return 'Car can go up to 180 km/h'

class bike(Vehicle):
  def max_speed(self):
    return 'Bike can go up to 120 km/h'

class truck(Vehicle):
  def max_speed(self):
    return 'Truck can go up to 90 km/h'

obj = [car(), bike(), truck()]

for vehicles in obj:
  print(vehicles.max_speed())
# Out:
# Car can go up to 180 km/h
# Bike can go up to 120 km/h
# Truck can go up to 90 km/h

# %% [markdown]
#  Q7. Create a program in python to demonstrate Polymorphism.
#  1. Make use of private and protected members using python name mangling techniques.

# %%
class Vehicle:
  def __init__(self, speed, fuel):
    self._speed = speed #Protected member
    self.__fuel = fuel  #Private member

  def display_info(self):
    print(f'Vehicle Speed: {self._speed} km/h')
    print(f'Vehicle Fuel: {self.__fuel} litres')

class car(Vehicle):
  def display_info(self):
    #Accessing protected member directly
    print(f"Car Speed: {self._speed} km/h")
    #Accessing private member using name mangling
    print(f"Car Fuel: {self._Vehicle__fuel} liters")

class bike(Vehicle):
  def display_info(self):
    print(f'Bike Speed: {self._speed} km/h')
    print(f'Bike Fuel: {self._Vehicle__fuel} litres')

v1 = Vehicle(200,40)
c1 = car(180,20)
b1 = bike(140,12)

obj = [v1, c1, b1]

for v in obj:
  v.display_info()
  print("-----------------------")
# Out:
# Vehicle Speed: 200 km/h
# Vehicle Fuel: 40 litres
# -----------------------
# Car Speed: 180 km/h
# Car Fuel: 20 liters
# -----------------------
# Bike Speed: 140 km/h
# Bike Fuel: 12 litres
# -----------------------

# %% [markdown]
# Q8. Given a list of 50 natural numbers from 1-50. Create a function that will take every element
#  from the list and return the square of each element. Use the python map and filter methods to
#  implement the function on the given list.

# %%
numbers = list(range(1,51))

def square(n):
  return n*n

squared_numbers = list(map(square,numbers))

print("Squares of numbers from 1 to 50:")
print(squared_numbers)

# (Optional): Using filter to get only squares > 1000
large_squares = list(filter(lambda x: x>1000, squared_numbers))
print("\nSquares greater than 1000:")
print(large_squares)
# Out:
# Squares of numbers from 1 to 50:
# [1, 4, 9, 16, 25, 36, 49, 64, 81, 100, 121, 144, 169, 196, 225, 256, 289, 324, 361, 400, 441, 484, 529, 576, 625, 676, 729, 784, 841, 900, 961, 1024, 1089, 1156, 1225, 1296, 1369, 1444, 1521, 1600, 1681, 1764, 1849, 1936, 2025, 2116, 2209, 2304, 2401, 2500]
#
# Squares greater than 1000:
# [1024, 1089, 1156, 1225, 1296, 1369, 1444, 1521, 1600, 1681, 1764, 1849, 1936, 2025, 2116, 2209, 2304, 2401, 2500]

# %% [markdown]
#  Q9. Create a class, Triangle. Its init() method should take self, angle1, angle2, and angle3 as
#  arguments.

# %%
class Triangle:
  def __init__(self,angle1,angle2,angle3):
    self.angle1 = angle1
    self.angle2 = angle2
    self.angle3 = angle3

#             ------
#(optional) for the provided Question

  def is_valid(self):
    if self.angle1 + self.angle2 + self.angle3 == 180:
      return True
    else:
      return False

  def display_angles(self):
      print("Triangle angles are:",self.angle1,self.angle2,self.angle3)

t1 = Triangle(60,60,60)
t1.display_angles()

if t1.is_valid():
  print("This is a vaild triangle🔺✅")
else:
  print("This is NOt a vaild triangle🔺✖️")
# Out:
# Triangle angles are: 60 60 60
# This is a vaild triangle🔺✅

# %% [markdown]
#  Q10. Create a class variable named number_of_sides and set it equal to 3.

# %%
class Triangle:
  number_of_sides = 3

t1 = Triangle()
print('Number of sides in a triangle:',t1.number_of_sides)
# Out:
# Number of sides in a triangle: 3

# %% [markdown]
#  Q11. Create a method named check_angles. The sum of a triangle's three angles should return
#  True if the sum is equal to 180, and False otherwise. The method should print whether the
#  angles belong to a triangle or not.

# %%
class triangle:
  number_of_sides = 3

  def __init__(self,angle1,angle2,angle3):
    self.angle1 = angle1
    self.angle2 = angle2
    self.angle3 = angle3

  def check_angles(self):
      total = self.angle1 + self.angle2 + self.angle3

      if total == 180:
        print('✅ These angles form a valid triangle')
        return True
      else:
        print("❌ These angles do not form a triangle")
        return False

t1 = triangle(60,90,30)
t1.check_angles()
# Out:
# ✅ These angles form a valid triangle
# True

# %% [markdown]
# 11.1 Write methods to verify if the triangle is an acute triangle or obtuse triangle.

# %%
class triangle:
  number_of_sides = 3

  def __init__(self,angle1,angle2,angle3):
    self.angle1 = angle1
    self.angle2 = angle2
    self.angle3 = angle3

  def check_angles(self):
    total = self.angle1 + self.angle2 + self.angle3

    if total == 180:
      print('✅ These angles form a valid triangle')
      return True
    else:
      print("❌ These angles do not form a triangle")
      return False

  def triangle_type(self):
    if self.check_angles():
      if (self.angle1<90 and self.angle2<90 and self.angle3<90):
        print("Its an acute triangle")
      elif (self.angle1>90 or self.angle2>90 or self.angle3>90):
        print("Its an Obtuse triangle")
      else:
        print("Its a Right triangle")
    else:
      print("🙆🏾Cannot check type - invalid triangle")

t1=triangle(60,60,60)
t1.triangle_type()
print("--"*10)

t2=triangle(100,40,40)
t2.triangle_type()
print("--"*10)
# Out:
# ✅ These angles form a valid triangle
# Its an acute triangle
# --------------------
# ✅ These angles form a valid triangle
# Its an Obtuse triangle
# --------------------

# %% [markdown]
#  11.2 Create an instance of the triangle class and call all the defined methods.

# %%
calling = triangle(60,70,50)
print("Number of sides:",triangle.number_of_sides)
calling.triangle_type()

calling2 = triangle(60,20,100)
print("\nNumber of sides:",triangle.number_of_sides)
calling2.triangle_type()
# Out:
# Number of sides: 3
# ✅ These angles form a valid triangle
# Its an acute triangle
#
# Number of sides: 3
# ✅ These angles form a valid triangle
# Its an Obtuse triangle

# %% [markdown]
#  11.3 Create three child classes of triangle class- isosceles_triangle, right_triangle and
#  equilateral_triangle.

# %%
class isosceles_triangle(triangle):
  def check_isosceles(self,side1,side2,side3):
    if self.check_angles():
      if side1==side2 or side2==side3 or side3==side1:
        print("It is an Isosceles Triangle")
      else:
        print("Not an Isosceles Triangle")
    else:
      print("🙆🏾Cannot check type - invalid triangle")

class right_triangle(triangle):
  def check_right(self):
    if self.check_angles():
      if (self.angle1==90 or self.angle2==90 or self.angle3==90):
        print("It is an Right Triangle 📐")
      else:
        print("Not a Right triangle✖️")
    else:
      print("🙆🏾Cannot check type - invalid triangle")

class equilateral_triangle(triangle):
  def check_equalateral(self,side1,side2,side3):
    if self.check_angles():
      if side1 == side2 == side3:
        print("It is an Equilateral Triangle 🟰")
      else:
        print("Not an Equilateral Triangle ⛔")
    else:
      print("🙆🏾Cannot check type - invalid triangle")

# %% [markdown]
# 11.4 Define methods which check for their properties.

# %%
iso = isosceles_triangle(60,60,60)
iso.check_isosceles(10,10,15)
print("----" * 10)

right = right_triangle(90,45,45)
right.check_right()
print("----" * 10)

equil = equilateral_triangle(60,60,60)
equil.check_equalateral(15,15,15)
print("----" * 10)

t1=triangle(60,60,60)
t1.triangle_type()
print("----" * 10)

t2=triangle(100,40,50)
t2.triangle_type()
# Out:
# ✅ These angles form a valid triangle
# It is an Isosceles Triangle
# ----------------------------------------
# ✅ These angles form a valid triangle
# It is an Right Triangle 📐
# ----------------------------------------
# ✅ These angles form a valid triangle
# It is an Equilateral Triangle 🟰
# ----------------------------------------
# ✅ These angles form a valid triangle
# Its an acute triangle
# ----------------------------------------
# ❌ These angles do not form a triangle
# 🙆🏾Cannot check type - invalid triangle

# %% [markdown]
#  Q12. Create a class isosceles_right_triangle which inherits from isosceles_triangle and
#  right_triangle.

# %%
class isosceles_right_triangle(isosceles_triangle,right_triangle):
  def check_isosceles_right(self,side1,side2,side3):

    print("Checking Isosceles Right Triangle Properties:")
    if self.check_angles():
      self.check_isosceles(side1,side2,side3)
      self.check_right()
      if (side1 == side2) and (90 in [self.angle1,self.angle2,self.angle3]):
        print("\nYes!! It is an Isosceles Right triangle")
      else:
        print("\nNO! It is NOT an Isosceles Right triangle")
    else:
       print("Invalid angles - cannot check")

# %% [markdown]
#  12.1 Define methods which check for their properties.

# %%
obj = isosceles_right_triangle(90,45,45)
obj.check_isosceles_right(5,5,6)
# Out:
# Checking Isosceles Right Triangle Properties:
# ✅ These angles form a valid triangle
# ✅ These angles form a valid triangle
# It is an Isosceles Triangle
# ✅ These angles form a valid triangle
# It is an Right Triangle 📐
#
# Yes!! It is an Isosceles Right triangle
